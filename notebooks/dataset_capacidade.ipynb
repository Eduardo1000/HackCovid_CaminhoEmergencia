# %%
import pandas as pd
import os

# %%
join_key = 'CO_UNIDADE'
data_folder='../BASE_DE_DADOS_CNES_202003'

# CARREGA AS INFORMAÇÕES DO NÚMERO DE LEITOS
print('numero leitos')
columns = ['CO_UNIDADE', 'QT_EXIST', 'QT_SUS']
leitos = pd.read_csv(os.path.join(data_folder, 'rlEstabComplementar202003.csv'), sep=';')
leitos = leitos[columns]
leitos = leitos.groupby('CO_UNIDADE').sum()
print(leitos.shape)
leitos
# Out:
# numero leitos
# (9627, 2)
#                                  QT_EXIST  QT_SUS
# CO_UNIDADE
# 1100012516500                           6       0
# 1100012679477                          45      45
# 1100020102091                          11      11
# 1100022494280                          36      31
# 1100022494299                          67      67
# ...                                   ...     ...
# CE00000000000000006580724000138         8       0
# PB00000000000000000000000005169         1       1
# PB00000000000000000000000007617        26      16
# PE00000000000000012047965000119        18       0
# SP00000000000000059302026000137       150       0
#
# [9627 rows x 2 columns]

# %%
# FILTRA OS TIPOS DE LEITO
columns = ["CO_LEITO", "DS_LEITO"]
# tipos_leito_escolhidos = ["51", "52", "74", "75", "76", "46", "34", "49"]
tipo_leito_key = 'TP_LEITO'
print('filtro tipos de leito')
tipo_leitos = pd.read_csv(os.path.join(data_folder, 'tbLeito202003.csv'), sep=';')
#tipo_leitos = tipo_leitos[columns].set_index(tipo_leito_key)
tipo_leitos
# leitos = leitos[leitos[tipo_leito_key].isin(tipos_leito_escolhidos)]
# Out:
# filtro tipos de leito
#     CO_LEITO                                           DS_LEITO  TP_LEITO
# 0          1                                 BUCO MAXILO FACIAL         1
# 1          2                                        CARDIOLOGIA         1
# 2          3                                     CIRURGIA GERAL         1
# 3          4                                     ENDOCRINOLOGIA         1
# 4          5                                  GASTROENTEROLOGIA         1
# ..       ...                                                ...       ...
# 63        93  UNIDADE DE CUIDADOS INTERMEDIARIOS NEONATAL CA...         3
# 64        94      UNIDADE DE CUIDADOS INTERMEDIARIOS PEDIATRICO         3
# 65        95          UNIDADE DE CUIDADOS INTERMEDIARIOS ADULTO         3
# 66        51                           UTI II ADULTO - COVID-19         3
# 67        52                       UTI II PEDIATRICA - COVID-19         3
#
# [68 rows x 3 columns]

# %%
leitos = leitos.set_index(tipo_leito_key).join(tipo_leitos, on=tipo_leito_key, lsuffix='_')
leitos = leitos.reset_index().drop(columns=[tipo_leito_key])
leitos = leitos.set_index(join_key)
leitos.to_csv(os.path.join(self.save_path, 'leitos.csv'))

# %%
# CARREGA AS INFORMAÇÕES DO ESTABELECIMENTO
columns = ['CO_CNES', 'NO_FANTASIA', 'NO_LOGRADOURO', 'NU_ENDERECO', 'NO_COMPLEMENTO', 'NO_BAIRRO', 'CO_CEP',
    'NU_LATITUDE', 'NU_LONGITUDE', 'NU_TELEFONE', 'TP_UNIDADE', 'CO_MUNICIPIO_GESTOR',
    'TP_ESTAB_SEMPRE_ABERTO', 'CO_TIPO_ESTABELECIMENTO', 'CO_ATIVIDADE_PRINCIPAL']
print('estabelecimento')
estabelecimentos = pd.read_csv(os.path.join(data_folder, 'tbEstabelecimento202003.csv'), sep=';', low_memory=False)
estabelecimentos = estabelecimentos[columns]
    # SELECIONA APENAS O MUNICIPIO DO RIO DE JANEIRO
estabelecimentos = estabelecimentos.loc[estabelecimentos['CO_MUNICIPIO_GESTOR'] == 330455].drop(
    columns=['CO_MUNICIPIO_GESTOR'])
estabelecimentos
# Out:
# estabelecimento
#         CO_CNES                                        NO_FANTASIA  \
# 112     2271249                            ONCOLOGISTAS ASSOCIADOS
# 124     2271257                            ONCOLOGISTAS ASSOCIADOS
# 174       32255                        VERA ALBUQUERQUE PSICO FONO
# 175       33731                            JULIANA DE MOURA CABRAL
# 183       55107                       ORLANDO TEIXEIRA MAIA JUNIOR
# ...         ...                                                ...
# 398708  3820572      HISTOCITO PATOLOGIA CIRURGICA E CITOPATOLOGIA
# 398709  3820599             SMS CF ARMANDO PALHARES AGUINAGA AP 51
# 398724  2291266  SMS RIO HOSPITAL MUNICIPAL FRANCISCO DA SILVA ...
# 399888  3008541                                UTI NEONATAL AMPARO
# 400127  6445152                          CLINICA DO CORPO E DA VOZ
#
#                               NO_LOGRADOURO NU_ENDERECO   NO_COMPLEMENTO  \
# 112        RUA DR CAETANO DE FARIA E CASTRO          25  SALAS 303 E 307
# 124                   RUA CARDOSO DE MORAES          61  SALAS 512 E 513
# 174                     RUA CONDE DE BONFIM         370         SALA 705
# 175       AVENIDA EMBAIXADOR ABELARDO BUENO           1  BL 01 SALA 201E
# 183                          FAME DE AMOEDO         104            LOJ A
# ...                                     ...         ...              ...
# 398708  AVENIDA NOSSA SENHORA DE COPACABANA         540          SL 1004
# 398709                        AV SANTA CRUZ         S/N              NaN
# 398724                            UBIRAJARA          25              NaN
# 399888                          RUA ESTRELA          27            PARTE
# 400127                          RUA URUGUAI         247      LOJAS A B C
#
#            NO_BAIRRO    CO_CEP   NU_LATITUDE  NU_LONGITUDE   NU_TELEFONE  \
# 112     CAMPO GRANDE  23052010           NaN           NaN  (21)33949816
# 124       BONSUCESSO  21032000           NaN           NaN  (21)25601885
# 174           TIJUCA  20520054   -22.9067678   -43.2395772           NaN
# 175      JACAREPAGUA  22775040   -22.9750781   -43.3650714      30420458
# 183          IPANEMA  22420020       -22.903       -43.208           NaN
# ...              ...       ...           ...           ...           ...
# 398708    COPACABANA  22020001           NaN           NaN      25496150
# 398709      REALENGO  21765020  -22.87887631  -43.42990318  21 2401-7787
# 398724         IRAJA  21230300       -22.903       -43.208   021 3715070
# 399888  RIO COMPRIDO  20251021           NaN           NaN  (21)25560022
# 400127        TIJUCA  20510060           NaN           NaN      22688943
#
#         TP_UNIDADE TP_ESTAB_SEMPRE_ABERTO  CO_TIPO_ESTABELECIMENTO  \
# 112             36                    NaN                      NaN
# 124             36                    NaN                      NaN
# 174             22                      N                     16.0
# 175             22                      N                     16.0
# 183             22                      N                     16.0
# ...            ...                    ...                      ...
# 398708          39                    NaN                      NaN
# 398709           2                      N                      1.0
# 398724           5                      S                      6.0
# 399888           7                    NaN                      NaN
# 400127          36                    NaN                      NaN
#
#         CO_ATIVIDADE_PRINCIPAL
# 112                        NaN
# 124                        NaN
# 174                        1.0
# 175                        1.0
# 183                        1.0
# ...                        ...
# 398708                     NaN
# 398709                    12.0
# 398724                     9.0
# 399888                     NaN
# 400127                     NaN
#
# [14083 rows x 14 columns]

# %%
# CARREGA OS TIPOS DE ESTABELECIMENTO
columns = ["CO_TIPO_ESTABELECIMENTO", "DS_TIPO_ESTABELECIMENTO"]
key_tipo = "CO_TIPO_ESTABELECIMENTO"
print('tipos estabelecimentos')
tipo_estabelecimentos = pd.read_csv(os.path.join(self.data_folder, 'tbTipoEstabelecimento202003.csv'), sep=';')
tipo_estabelecimentos = tipo_estabelecimentos[columns].set_index(key_tipo)
estabelecimentos = estabelecimentos.set_index(key_tipo).join(tipo_estabelecimentos, on='CO_TIPO_ESTABELECIMENTO', lsuffix='_')
estabelecimentos = estabelecimentos.reset_index().drop(columns=[key_tipo])
# FILTRA OS ESTABELECIMENTOS DE INTERESSE
EXCLUDE_COLUMNS = [
    "CENTRAL DE GESTAO EM SAUDE", "CENTRAL DE REGULACAO", "CENTRAL DE ABASTECIMENTO",
    "CENTRAL DE TRANSPLANTE", "CENTRO DE ASSISTENCIA OBSTETRICA E NEONATAL NORMAL", "FARMACIA",
    "UNIDADE DE ATENCAO HEMATOLOGICA E/OU HEMOTERAPICA", "UNIDADE DE ATENCAO PSICOSSOCIAL",
    "UNIDADE DE APOIO DIAGNOSTICO","UNIDADE DE TERAPIAS ESPECIAIS", "LABORATORIO DE PROTESE DENTARIA",
    "UNIDADE DE VIGILANCIA DE ZOONOSES","LABORATORIO DE SAUDE PUBLICA",
    "CENTRO DE REFERENCIA EM SAUDE DO TRABALHADOR","SERVICO DE VERIFICACAO DE OBITO","CENTRO DE IMUNIZACAO"]
estabelecimentos = estabelecimentos[~estabelecimentos['DS_TIPO_ESTABELECIMENTO'].isin(EXCLUDE_COLUMNS)]
# Out:
# tipos estabelecimentos
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-63-446635a45f12> in <module>
#       3 key_tipo = "CO_TIPO_ESTABELECIMENTO"
#       4 print('tipos estabelecimentos')
# ----> 5 tipo_estabelecimentos = pd.read_csv(os.path.join(self.data_folder, 'tbTipoEstabelecimento202003.csv'), sep=';')
#       6 tipo_estabelecimentos = tipo_estabelecimentos[columns].set_index(key_tipo)
#       7 estabelecimentos = estabelecimentos.set_index(key_tipo).join(tipo_estabelecimentos, on='CO_TIPO_ESTABELECIMENTO', lsuffix='_')
#
# NameError: name 'self' is not defined

# %%
estabelecimentos = estabelecimentos.set_index(join_key)
print('filtro estabelecimentos')
estabelecimentos
# Out:
# filtro estabelecimentos
#                                 CO_CNES  \
# CO_UNIDADE
# RJ0000330455000028000107000825  2271249
# RJ0000330455000028000107000744  2271257
# 3304550032255                     32255
# 3304550033731                     33731
# 3304550055107                     55107
# ...                                 ...
# 3304553820572                   3820572
# 3304553820599                   3820599
# 3304552291266                   2291266
# 3304553008541                   3008541
# 3304556445152                   6445152
#
#                                                                       NO_FANTASIA  \
# CO_UNIDADE
# RJ0000330455000028000107000825                            ONCOLOGISTAS ASSOCIADOS
# RJ0000330455000028000107000744                            ONCOLOGISTAS ASSOCIADOS
# 3304550032255                                         VERA ALBUQUERQUE PSICO FONO
# 3304550033731                                             JULIANA DE MOURA CABRAL
# 3304550055107                                        ORLANDO TEIXEIRA MAIA JUNIOR
# ...                                                                           ...
# 3304553820572                       HISTOCITO PATOLOGIA CIRURGICA E CITOPATOLOGIA
# 3304553820599                              SMS CF ARMANDO PALHARES AGUINAGA AP 51
# 3304552291266                   SMS RIO HOSPITAL MUNICIPAL FRANCISCO DA SILVA ...
# 3304553008541                                                 UTI NEONATAL AMPARO
# 3304556445152                                           CLINICA DO CORPO E DA VOZ
#
#                                                       NO_LOGRADOURO  \
# CO_UNIDADE
# RJ0000330455000028000107000825     RUA DR CAETANO DE FARIA E CASTRO
# RJ0000330455000028000107000744                RUA CARDOSO DE MORAES
# 3304550032255                                   RUA CONDE DE BONFIM
# 3304550033731                     AVENIDA EMBAIXADOR ABELARDO BUENO
# 3304550055107                                        FAME DE AMOEDO
# ...                                                             ...
# 3304553820572                   AVENIDA NOSSA SENHORA DE COPACABANA
# 3304553820599                                         AV SANTA CRUZ
# 3304552291266                                             UBIRAJARA
# 3304553008541                                           RUA ESTRELA
# 3304556445152                                           RUA URUGUAI
#
#                                NU_ENDERECO   NO_COMPLEMENTO     NO_BAIRRO  \
# CO_UNIDADE
# RJ0000330455000028000107000825          25  SALAS 303 E 307  CAMPO GRANDE
# RJ0000330455000028000107000744          61  SALAS 512 E 513    BONSUCESSO
# 3304550032255                          370         SALA 705        TIJUCA
# 3304550033731                            1  BL 01 SALA 201E   JACAREPAGUA
# 3304550055107                          104            LOJ A       IPANEMA
# ...                                    ...              ...           ...
# 3304553820572                          540          SL 1004    COPACABANA
# 3304553820599                          S/N              NaN      REALENGO
# 3304552291266                           25              NaN         IRAJA
# 3304553008541                           27            PARTE  RIO COMPRIDO
# 3304556445152                          247      LOJAS A B C        TIJUCA
#
#                                   CO_CEP   NU_LATITUDE  NU_LONGITUDE  \
# CO_UNIDADE
# RJ0000330455000028000107000825  23052010           NaN           NaN
# RJ0000330455000028000107000744  21032000           NaN           NaN
# 3304550032255                   20520054   -22.9067678   -43.2395772
# 3304550033731                   22775040   -22.9750781   -43.3650714
# 3304550055107                   22420020       -22.903       -43.208
# ...                                  ...           ...           ...
# 3304553820572                   22020001           NaN           NaN
# 3304553820599                   21765020  -22.87887631  -43.42990318
# 3304552291266                   21230300       -22.903       -43.208
# 3304553008541                   20251021           NaN           NaN
# 3304556445152                   20510060           NaN           NaN
#
#                                  NU_TELEFONE  TP_UNIDADE  \
# CO_UNIDADE
# RJ0000330455000028000107000825  (21)33949816          36
# RJ0000330455000028000107000744  (21)25601885          36
# 3304550032255                            NaN          22
# 3304550033731                       30420458          22
# 3304550055107                            NaN          22
# ...                                      ...         ...
# 3304553820572                       25496150          39
# 3304553820599                   21 2401-7787           2
# 3304552291266                    021 3715070           5
# 3304553008541                   (21)25560022           7
# 3304556445152                       22688943          36
#
#                                TP_ESTAB_SEMPRE_ABERTO  \
# CO_UNIDADE
# RJ0000330455000028000107000825                    NaN
# RJ0000330455000028000107000744                    NaN
# 3304550032255                                       N
# 3304550033731                                       N
# 3304550055107                                       N
# ...                                               ...
# 3304553820572                                     NaN
# 3304553820599                                       N
# 3304552291266                                       S
# 3304553008541                                     NaN
# 3304556445152                                     NaN
#
#                                 CO_TIPO_ESTABELECIMENTO  \
# CO_UNIDADE
# RJ0000330455000028000107000825                      NaN
# RJ0000330455000028000107000744                      NaN
# 3304550032255                                      16.0
# 3304550033731                                      16.0
# 3304550055107                                      16.0
# ...                                                 ...
# 3304553820572                                       NaN
# 3304553820599                                       1.0
# 3304552291266                                       6.0
# 3304553008541                                       NaN
# 3304556445152                                       NaN
#
#                                 CO_ATIVIDADE_PRINCIPAL
# CO_UNIDADE
# RJ0000330455000028000107000825                     NaN
# RJ0000330455000028000107000744                     NaN
# 3304550032255                                      1.0
# 3304550033731                                      1.0
# 3304550055107                                      1.0
# ...                                                ...
# 3304553820572                                      NaN
# 3304553820599                                     12.0
# 3304552291266                                      9.0
# 3304553008541                                      NaN
# 3304556445152                                      NaN
#
# [14083 rows x 14 columns]

# %%
leitos = pd.read_csv(os.path.join(data_folder, 'dataset', 'Leitos SIH_SUS_RJ.csv'), encoding='latin1')
leitos
# Out:
#       UF         MunicÃ­pio  \
# 0     RJ  RIO DE JANEIRO-RJ
# 1     RJ  RIO DE JANEIRO-RJ
# 2     RJ  RIO DE JANEIRO-RJ
# 3     RJ  RIO DE JANEIRO-RJ
# 4     RJ  RIO DE JANEIRO-RJ
# ...   ..                ...
# 1545  RJ  RIO DE JANEIRO-RJ
# 1546  RJ  RIO DE JANEIRO-RJ
# 1547  RJ  RIO DE JANEIRO-RJ
# 1548  RJ  RIO DE JANEIRO-RJ
# 1549  RJ  RIO DE JANEIRO-RJ
#
#                               Estabelecimento de saÃºde     CNES  \
# 0     MS INST NACIONAL DE TRAUMATOLOGIA E ORTOPEDIA ...  2273276
# 1                                     CLINICA DA GAVEA   2269406
# 2                       SMS IMAS JULIANO MOREIRA AP 40   2269996
# 3     SEAP CGSP RJ HOSP PENAL PSIQUIATRICO ROBERTO M...  2270188
# 4              SCMRJ SANTA CASA HOSPITAL N S DAS DORES   2291282
# ...                                                 ...      ...
# 1545                            HOSPITAL QUALI IPANEMA   3543579
# 1546                      NOTRE DAME INTERMEDICA SAUDE   9614133
# 1547                                HOSPITAL DO AMPARO   3013014
# 1548                                  HOSPITAL BALBINO   2271451
# 1549                            HOSPITAL QUALI IPANEMA   3543579
#
#         Espec./Tipo do Leito  Qtd Exist.  Qtd SUS
# 0     ORTOPEDIATRAUMATOLOGIA         239      239
# 1                PSIQUIATRIA         220        0
# 2                PSIQUIATRIA         170      170
# 3                PSIQUIATRIA         161      161
# 4                   CRONICOS         160       80
# ...                      ...         ...      ...
# 1545      BUCO MAXILO FACIAL           1        0
# 1546     PEDIATRIA CIRURGICA           1        0
# 1547      BUCO MAXILO FACIAL           1        0
# 1548                TORAXICA           1        0
# 1549                PLASTICA           1        0
#
# [1550 rows x 7 columns]

# %%
estabelecimentos.to_csv(os.path.join(self.save_path, 'estabelecimentos.csv'))

# %%
estabelecimentos.shape, leitos.shape#.unique()
# Out:
# ((14083, 14), (1550, 7))

# %%
# Concatena os dados
dataframe = estabelecimentos.set_index('CO_CNES').join(leitos.set_index('CNES'), how='right')
print('dados concatenados')
dataframe = dataframe.drop(columns=['NO_FANTASIA', 'NO_COMPLEMENTO', 'NU_TELEFONE','UF', 'MunicÃ­pio', 'NO_LOGRADOURO', 'NU_ENDERECO', 'CO_CEP'])
# Out:
# dados concatenados

# %%
dataframe.groupby('Estabelecimento de saÃºde')
# Out:
#                  NO_BAIRRO NU_LATITUDE NU_LONGITUDE  TP_UNIDADE  \
# 2269341        VILA ISABEL     -22.903      -43.208           7
# 2269341        VILA ISABEL     -22.903      -43.208           7
# 2269341        VILA ISABEL     -22.903      -43.208           7
# 2269341        VILA ISABEL     -22.903      -43.208           7
# 2269341        VILA ISABEL     -22.903      -43.208           7
# ...                    ...         ...          ...         ...
# 9614133            ANDARAI     -22.903      -43.208           5
# 9614133            ANDARAI     -22.903      -43.208           5
# 9614133            ANDARAI     -22.903      -43.208           5
# 9614133            ANDARAI     -22.903      -43.208           5
# 9640665  ENGENHO DE DENTRO         NaN          NaN          36
#
#         TP_ESTAB_SEMPRE_ABERTO  CO_TIPO_ESTABELECIMENTO  \
# 2269341                      S                      6.0
# 2269341                      S                      6.0
# 2269341                      S                      6.0
# 2269341                      S                      6.0
# 2269341                      S                      6.0
# ...                        ...                      ...
# 9614133                      S                      6.0
# 9614133                      S                      6.0
# 9614133                      S                      6.0
# 9614133                      S                      6.0
# 9640665                      S                      6.0
#
#          CO_ATIVIDADE_PRINCIPAL          Estabelecimento de saÃºde  \
# 2269341                     9.0  SMS RIO HOSPITAL MUNICIPAL JESUS
# 2269341                     9.0  SMS RIO HOSPITAL MUNICIPAL JESUS
# 2269341                     9.0  SMS RIO HOSPITAL MUNICIPAL JESUS
# 2269341                     9.0  SMS RIO HOSPITAL MUNICIPAL JESUS
# 2269341                     9.0  SMS RIO HOSPITAL MUNICIPAL JESUS
# ...                         ...                                ...
# 9614133                     9.0      NOTRE DAME INTERMEDICA SAUDE
# 9614133                     9.0      NOTRE DAME INTERMEDICA SAUDE
# 9614133                     9.0      NOTRE DAME INTERMEDICA SAUDE
# 9614133                     9.0      NOTRE DAME INTERMEDICA SAUDE
# 9640665                     7.0                         LOG HEALT
#
#                                   Espec./Tipo do Leito  Qtd Exist.  Qtd SUS
# 2269341                              PEDIATRIA CLINICA          38       38
# 2269341              CIRURGICO/DIAGNOSTICO/TERAPEUTICO          12       12
# 2269341                                       CRONICOS          10       10
# 2269341  UNIDADE DE CUIDADOS INTERMEDIARIOS PEDIATRICO           9        9
# 2269341                       UTI PEDIATRICA - TIPO II           8        8
# ...                                                ...         ...      ...
# 9614133                      UTI PEDIATRICA - TIPO III           9        0
# 9614133                             UNIDADE ISOLAMENTO           4        0
# 9614133                                 CIRURGIA GERAL           3        0
# 9614133                            PEDIATRIA CIRURGICA           1        0
# 9640665                            UTI ADULTO - TIPO I          21        0
#
# [1550 rows x 11 columns]

# %%
dataframe['TP_UNIDADE'].value_counts()
# Out:
# 5     1147
# 7      311
# 36      29
# 62      16
# 70      11
# 69      10
# 15       9
# 20       6
# 77       4
# 21       4
# 22       2
# 61       1
# Name: TP_UNIDADE, dtype: int64

# %%
dataframe.to_csv(os.path.join('.', 'capacidade.csv'))
